# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
_11 = pd.read_csv('catBoost_ensemble_11.csv')['prediction']
_12 = pd.read_csv('catBoost_ensemble_12.csv')['prediction']
_14 = pd.read_csv('catBoost_ensemble_14.csv')['prediction']
_11_new5h = pd.read_csv('catBoost_ensemble_11_new5h.csv')['prediction']

best = pd.read_csv('catBoost_ensemble_12_new5h_8rands_cleanX.csv')['prediction']

xgb_auto_ml = pd.read_csv('prediction.csv')['prediction']

# %%
s = 0
e = s + 200


# plt.ylim(3500,5000)

# sns.lineplot(_11[s:e],color='red')
# sns.lineplot(_12[s:e],color='blue')
sns.lineplot(xgb_auto_ml[s:e],color='blue')
sns.lineplot(best[s:e],color='red')
# sns.lineplot(_14[s:e],color='green')
# sns.lineplot(_11_new5h[s:e],color='black')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/ML/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/ML/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniconda/base/envs/ML/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
_mean = (xgb_auto_ml*0.1 + best*0.9)

# %%
_mean.to_csv('ens_xgb01_best09.csv',index=True)

# %%
_12_105 = _12 * 1.05
_12_105.to_csv('ens_12_105_cat.csv',index=True)
